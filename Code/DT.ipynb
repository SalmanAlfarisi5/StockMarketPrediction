# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, roc_curve
)

# %%
merged_df = pd.read_csv('../Data/merged.csv')
merged_df['Date'] = pd.to_datetime(merged_df['Date'], format='mixed', dayfirst=True, errors='coerce')
merged_df = merged_df.sort_values(["Symbol", "Date"])

merged_df.head()
# Out:
#   Symbol  GICS Sector    Headquarters Location Founded       Date       Close  \
# 0      A  Health Care  Santa Clara, California    1999 2020-10-15  105.320000
# 1      A  Health Care  Santa Clara, California    1999 2020-10-16  106.699997
# 2      A  Health Care  Santa Clara, California    1999 2020-10-19  105.489998
# 3      A  Health Care  Santa Clara, California    1999 2020-10-20  105.610001
# 4      A  Health Care  Santa Clara, California    1999 2020-10-21  104.830002
#
#     Volume  News - Positive Sentiment  News - Negative Sentiment  \
# 0   723000                        1.0                        0.0
# 1  1039400                        0.0                        0.0
# 2   636000                        0.0                        0.0
# 3   771000                        2.0                        0.0
# 4   894000                        0.0                        0.0
#
#    News - New Products  ...  Close_lag2  Close_lag3  Close_lag4  Close_lag5  \
# 0                  0.0  ...  105.419998  105.430000  105.760002  104.160004
# 1                  1.0  ...  105.059998  105.419998  105.430000  105.760002
# 2                  1.0  ...  105.320000  105.059998  105.419998  105.430000
# 3                  0.0  ...  106.699997  105.320000  105.059998  105.419998
# 4                  0.0  ...  105.489998  106.699997  105.320000  105.059998
#
#    Close_lag6  Close_lag7  Close_lag8  Close_lag9  Close_lag10  Profit
# 0  103.879997  101.629997  103.120003  100.010002   101.220001       1
# 1  104.160004  103.879997  101.629997  103.120003   100.010002       1
# 2  105.760002  104.160004  103.879997  101.629997   103.120003       0
# 3  105.430000  105.760002  104.160004  103.879997   101.629997       1
# 4  105.419998  105.430000  105.760002  104.160004   103.879997       0
#
# [5 rows x 32 columns]

# %%
lag_cols   = [f"Close_lag{k}" for k in range(1, 11)]
news_cols  = [c for c in merged_df.columns if c.startswith("News -")]
num_features  = lag_cols + ["Volume"] + news_cols      

merged_df = pd.get_dummies(merged_df, columns=["GICS Sector"], drop_first=True, dtype="int")

sector_dummies = [c for c in merged_df.columns if c.startswith("GICS Sector_")]
feature_cols   = num_features + sector_dummies

cutoff_date = merged_df["Date"].quantile(0.8)

train = merged_df[merged_df["Date"] <= cutoff_date]
test  = merged_df[merged_df["Date"]  > cutoff_date]

X_train, y_train = train[feature_cols], train["Profit"]
X_test,  y_test  = test [feature_cols], test ["Profit"]

# %%
tree = DecisionTreeClassifier(
    criterion="gini",
    max_depth=None,
    min_samples_leaf=10,
    random_state=42
)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=10, random_state=42)

# %%
y_pred      = tree.predict(X_test)
y_pred_prob = tree.predict_proba(X_test)[:, 1]

accuracy  = accuracy_score (y_test, y_pred)
precision = precision_score(y_test, y_pred, zero_division=0)
recall    = recall_score   (y_test, y_pred, zero_division=0)
f1        = f1_score       (y_test, y_pred, zero_division=0)
roc_auc   = roc_auc_score  (y_test, y_pred_prob)

print(f"Accuracy : {accuracy :.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall   :.4f}")
print(f"F1-score : {f1       :.4f}")
print(f"ROC-AUC  : {roc_auc  :.4f}")
# Out:
# Accuracy : 0.5058
# Precision: 0.4957
# Recall   : 0.5061
# F1-score : 0.5009
# ROC-AUC  : 0.5071

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="grey")
plt.xlabel("False-Positive Rate")
plt.ylabel("True-Positive Rate")
plt.title("ROC Curve - Decision Tree")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Try using AAPL only
aapl = merged_df[merged_df['Symbol'] == 'AAPL'].copy()

lag_cols  = [f"Close_lag{k}" for k in range(1, 11)]

cutoff_date = aapl["Date"].quantile(0.8)

train = aapl[aapl["Date"] <= cutoff_date]
test  = aapl[aapl["Date"]  > cutoff_date]

X_train, y_train = train[feature_cols], train["Profit"]
X_test,  y_test  = test [feature_cols], test ["Profit"]

# %%
tree = DecisionTreeClassifier(
    criterion="gini",
    max_depth=None,
    min_samples_leaf=10,
    random_state=42
)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=10, random_state=42)

# %%
y_pred      = tree.predict(X_test)
y_pred_prob = tree.predict_proba(X_test)[:, 1]

accuracy  = accuracy_score (y_test, y_pred)
precision = precision_score(y_test, y_pred, zero_division=0)
recall    = recall_score   (y_test, y_pred, zero_division=0)
f1        = f1_score       (y_test, y_pred, zero_division=0)
roc_auc   = roc_auc_score  (y_test, y_pred_prob)

print(f"Accuracy : {accuracy :.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall   :.4f}")
print(f"F1-score : {f1       :.4f}")
print(f"ROC-AUC  : {roc_auc  :.4f}")
# Out:
# Accuracy : 0.5698
# Precision: 0.5714
# Recall   : 0.5581
# F1-score : 0.5647
# ROC-AUC  : 0.5414

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="grey")
plt.xlabel("False-Positive Rate")
plt.ylabel("True-Positive Rate")
plt.title("ROC Curve - Decision Tree (AAPL)")
plt.legend()
plt.tight_layout()
plt.show()
